# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data= pd.read_csv('EDA_Shark_Tank_India.xlsx - Sheet1.csv')

# %%
data.head()
# Out:
#    episode_number  pitch_number           brand_name  \
# 0               1             1  BluePine Industries
# 1               1             2        Booz scooters
# 2               1             3  Heart up my Sleeves
# 3               2             4           Tagz Foods
# 4               2             5       Head and Heart
#
#                                             idea  deal  pitcher_ask_amount  \
# 0                                   Frozen Momos     1                50.0
# 1  Renting e-bike for mobility in private spaces     1                40.0
# 2                             Detachable Sleeves     1                25.0
# 3                           Healthy Potato Chips     1                70.0
# 4                       Brain Development Course     0                50.0
#
#    ask_equity  ask_valuation  deal_amount  deal_equity  ...  ashneer_deal  \
# 0         5.0        1000.00         75.0        16.00  ...             1
# ...

# %% [markdown]
# 1 : find the number of episode?

# %%
q=data['episode_number'].unique()
print('the total number of episode are', len(q))
# Out:
# the total number of episode are 35

# %% [markdown]
# 2 :max,min,mean,of asked amount, asked equity, asked valuation?

# %%
data['pitcher_ask_amount'].max()
# Out:
# 30000.0

# %%
data['pitcher_ask_amount'].min()
# Out:
# 0.00101

# %%
data['pitcher_ask_amount'].mean()
# Out:
# 319.8547094871795

# %% [markdown]
# 3 :max & min asked-equity , asked-valuation and asked amount episode-wise?

# %%
data['ask_valuation'].max()
# Out:
# 120000.0

# %%
data['ask_valuation'].min()
# Out:
# 0.01

# %%
data['ask_valuation'].mean()
# Out:
# 3852.4624786324785

# %%
df['ask_equity'].max()
# Out:
# 25.0

# %%
df['ask_equity'].min()
# Out:
# 0.25

# %%
data['ask_equity'].mean()
# Out:
# 5.188034188034188

# %% [markdown]
# 4 : Brand names in which 2,3,or 4 sharks are invested?

# %%
Brand_name=data.loc[(data['total_sharks_invested']>1)&(data['total_sharks_invested']<5),['brand_name','total_sharks_invested']]
Brand_name
# Out:
#                          brand_name  total_sharks_invested
# 0               BluePine Industries                      3
# 1                     Booz scooters                      2
# 2               Heart up my Sleeves                      2
# 9                             Cosiq                      2
# 11                           Bummer                      2
# 12                      Revamp Moto                      2
# 18               Raising Superstars                      2
# 21                     Beyond Snack                      2
# 22   Vivalyf Innovations- Easy Life                      2
# 24                            Altor                      2
# 25                            Ariro                      2
# 27                          Nuutjob                      3
# 28                         Meatyour                      3
# 29                        EventBeep                      3
# 32                            Farda                      2
# ...

# %% [markdown]
# 5 : Episode wise minimum and maximum of sharks invested?

# %%
sharks=data.groupby('episode_number')['total_sharks_invested'].agg([max,min])
sharks
# Out:
#                 max  min
# episode_number
# 1                 3    2
# 2                 1    0
# 3                 1    0
# 4                 2    0
# 5                 2    0
# 6                 5    0
# 7                 2    0
# 8                 2    1
# 9                 2    0
# 10                3    3
# 11                2    0
# 12                3    0
# 13                4    2
# 14                2    0
# 15                3    1
# 16                2    0
# 17                5    0
# 18                1    0
# 19                4    0
# 20                5    0
# 21                3    1
# 22                3    0
# 23                1    0
# 24                2    0
# 25                5    0
# 26                1    0
# 27                4    0
# 28                3    0
# 29                3    0
# 30                2    0
# 31                1    0
# 32                1    0
# 33                3    0
# 34                4    0
# 35                4    0

# %% [markdown]
# 6 : minimum & maximum sharks invested in each brand?

# %%
pd.options.display.max_rows = None
max_or_min= data.groupby('brand_name')['total_sharks_invested'].agg([max,min]).style

max_or_min.background_gradient(cmap='vlag')
max_or_min
# Out:
# <style type="text/css">
# #T_edb28_row0_col0, #T_edb28_row0_col1, #T_edb28_row10_col0, #T_edb28_row10_col1, #T_edb28_row11_col0, #T_edb28_row11_col1, #T_edb28_row21_col0, #T_edb28_row21_col1, #T_edb28_row36_col0, #T_edb28_row36_col1, #T_edb28_row39_col0, #T_edb28_row39_col1, #T_edb28_row47_col0, #T_edb28_row47_col1, #T_edb28_row48_col0, #T_edb28_row48_col1, #T_edb28_row52_col0, #T_edb28_row52_col1, #T_edb28_row64_col0, #T_edb28_row64_col1, #T_edb28_row69_col0, #T_edb28_row69_col1, #T_edb28_row70_col0, #T_edb28_row70_col1, #T_edb28_row71_col0, #T_edb28_row71_col1, #T_edb28_row76_col0, #T_edb28_row76_col1, #T_edb28_row79_col0, #T_edb28_row79_col1, #T_edb28_row80_col0, #T_edb28_row80_col1, #T_edb28_row81_col0, #T_edb28_row81_col1, #T_edb28_row87_col0, #T_edb28_row87_col1, #T_edb28_row89_col0, #T_edb28_row89_col1, #T_edb28_row95_col0, #T_edb28_row95_col1, #T_edb28_row100_col0, #T_edb28_row100_col1, #T_edb28_row104_col0, #T_edb28_row104_col1 {
#   background-color: #87a0c4;
# ...

# %% [markdown]
# 7 : Brand names who ask for 1 crore and got a deal?

# %%
data[(data["pitcher_ask_amount"] == 100) & (data["deal"] == 1)][["brand_name","pitcher_ask_amount","deal_amount"]]
# Out:
#              brand_name  pitcher_ask_amount  deal_amount
# 12          Revamp Moto               100.0        100.0
# 39    The Renal Project               100.0        100.0
# 55                 Otua               100.0          1.0
# 64           Get a Whey               100.0        100.0
# 71         Namhya Foods               100.0         50.0
# 79  Sunfox Technologies               100.0        100.0
# 87   Insurance Samadhan               100.0        100.0

# %% [markdown]
# 8 : Brand names where deal equity is between 0 to 50?

# %%
data[(data["deal_equity"]  >= 0) & (data["deal_equity"] <=50)][["brand_name", "ask_equity","deal_equity"]]
# Out:
#                          brand_name  ask_equity  deal_equity
# 0               BluePine Industries        5.00        16.00
# 1                     Booz scooters       15.00        50.00
# 2               Heart up my Sleeves       10.00        30.00
# 3                        Tagz Foods        1.00         2.75
# 4                    Head and Heart        5.00         0.00
# 5                      Agro tourism        5.00         0.00
# 6                       Qzense Labs        0.25         0.00
# 7                         Peeschute        4.00         6.00
# 8                              NOCD        2.00        15.00
# 9                             Cosiq        7.50        25.00
# 10                     JhaJi Achaar       10.00         0.00
# 11                           Bummer        4.00         7.50
# 12                      Revamp Moto        1.00         1.50
# 13                     Hungry Heads        5.00         0.00
# ...

# %% [markdown]
# 9 : find the numbers of brand participated in each episode?

# %%
shark=data.groupby('episode_number')['brand_name'].count()
shark
# Out:
# episode_number
# 1     3
# 2     3
# 3     3
# 4     3
# 5     3
# 6     3
# 7     3
# 8     3
# 9     3
# 10    3
# 11    3
# 12    3
# 13    3
# 14    3
# 15    3
# 16    4
# 17    4
# 18    4
# 19    4
# 20    3
# 21    3
# 22    4
# 23    4
# 24    3
# 25    3
# 26    3
# 27    4
# 28    3
# 29    3
# 30    4
# 31    4
# 32    4
# 33    4
# 34    4
# 35    3
# Name: brand_name, dtype: int64

# %% [markdown]
# 10 : How many sharks participated in this show and what were thier names?

# %%
print("total number of sharks in this data:",len(data.columns[11:18]))
shark_present=data.columns[11:18]
print("Names of the Sharks are: ", """ashneer, anupam, aman, namita,
       vineeta, peyush, ghazal"""
      )
# Out:
# total number of sharks in this data: 7
# Names of the Sharks are:  ashneer, anupam, aman, namita,
#        vineeta, peyush, ghazal

# %% [markdown]
# 11 : find the appearance of each sharks?

# %%
ab=data[["ashneer_present","anupam_present","aman_present","namita_present","vineeta_present","peyush_present","ghazal_present"]]
Present=ab.sum()
Present
# Out:
# ashneer_present     98
# anupam_present     117
# aman_present        98
# namita_present     106
# vineeta_present     66
# peyush_present      88
# ghazal_present      26
# dtype: int64

# %% [markdown]
# 12 : How many enterpreneurs were present?

# %%
data["pitch_number"].nunique()
# Out:
# 117

# %% [markdown]
# 13 : How many times each shark invested the deal?

# %%
data['ashneer_deal'].sum()
# Out:
# 21

# %%
data['anupam_deal'].sum()
# Out:
# 24

# %%
data['aman_deal'].sum()
# Out:
# 28

# %%
data['namita_deal'].sum()
# Out:
# 22

# %%
data['vineeta_deal'].sum()
# Out:
# 15

# %%
data['peyush_deal'].sum()
# Out:
# 27

# %%
print("No.of deals invested by each shark:")
for i in data.columns[18:25]:
    s=data[i].sum()
    print(i,s)
# Out:
# No.of deals invested by each shark:
# ashneer_deal 21
# anupam_deal 24
# aman_deal 28
# namita_deal 22
# vineeta_deal 15
# peyush_deal 27
# ghazal_deal 7

# %% [markdown]
# 14 : Find the equity percent that each sharks gets?

# %%
l = []
for i in data.columns[18:25]:
    x=data[data[i]==1]
    s=x["equity_per_shark"].sum()
    l.append(s)
    print(i,"total equity",s)
# Out:
# ashneer_deal total equity 93.249999999
# anupam_deal total equity 166.35
# aman_deal total equity 160.263333334
# namita_deal total equity 134.78333333400002
# vineeta_deal total equity 131.533333333
# peyush_deal total equity 315.84999999999997
# ghazal_deal total equity 46.7

# %%
for i in data.columns[18:25]:
    x=data[data[i]==1]
    s=x["equity_per_shark"].sum()
    
    print(i,"Equity percent:",s*100/sum(l))
# Out:
# ashneer_deal Equity percent: 8.891707112316801
# anupam_deal Equity percent: 15.862042661123454
# aman_deal Equity percent: 15.281658132598478
# namita_deal Equity percent: 12.852052800434812
# vineeta_deal Equity percent: 12.542154161032869
# peyush_deal Equity percent: 30.117380069226584
# ghazal_deal Equity percent: 4.453005063266999

# %% [markdown]
# 15 : Find the total number of amount invested in this show?

# %%
data['deal_amount'].sum()
# Out:
# 3742.00106

# %%
x = data[data["deal"]==1]
x['deal_amount'].sum()
# Out:
# 3642.00106
